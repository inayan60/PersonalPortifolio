# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://transparencia.joinville.sc.gov.br/epublica-portal/rest/joinville/api/v1/despesaOrcamentaria"

# %%
url = "https://transparencia.joinville.sc.gov.br/epublica-portal/rest/joinville/api/v1/despesaOrcamentaria"
params = {
    "periodo_inicial": "01/2025",
    "periodo_final": "08/2025",
    "codigo_unidade": 0
}
response = requests.get(url, params=params)
data = response.json()

# %%
registros = data["registros"]

# %%
df = pd.json_normalize([r["registro"] for r in registros])

# %%
df.columns
# Out:
# Index(['listMovimentos', 'classificacaoCompleta.classificacaoCompleta',
#        'despesa.funcao.codigo', 'despesa.funcao.denominacao',
#        'despesa.subfuncao.codigo', 'despesa.subfuncao.denominacao',
#        'despesa.programa.codigo', 'despesa.programa.denominacao',
#        'despesa.acao.codigo', 'despesa.acao.denominacao',
#        'naturezaDespesa.categoriaEconomica.codigo',
#        'naturezaDespesa.categoriaEconomica.codigoCompleto',
#        'naturezaDespesa.categoriaEconomica.denominacao',
#        'naturezaDespesa.grupo.codigo', 'naturezaDespesa.grupo.codigoCompleto',
#        'naturezaDespesa.grupo.denominacao',
#        'naturezaDespesa.modalidadeAplicacao.codigo',
#        'naturezaDespesa.modalidadeAplicacao.codigoCompleto',
#        'naturezaDespesa.modalidadeAplicacao.denominacao',
#        'naturezaDespesa.elemento.codigo',
#        'naturezaDespesa.elemento.codigoCompleto',
#        'naturezaDespesa.elemento.denominacao', 'fonteRecurso.codigo',
#        'fonteRecurso.denominacao', 'exercicio.exercicio',
#        'unidadeOrcamentaria.codigo', 'unidadeOrcamentaria.denominacao',
#        'unidadeOrcamentaria.unidadeGestora.codigo',
#        'unidadeOrcamentaria.unidadeGestora.denominacao',
#        'unidadeOrcamentaria.unidadeOrcamentariaPai.codigo',
#        'unidadeOrcamentaria.unidadeOrcamentariaPai.denominacao',
#        'naturezaDespesa'],
#       dtype='object')

# %%
df.describe()
# Out:
#        despesa.funcao.codigo  despesa.subfuncao.codigo  \
# count           23757.000000              23757.000000
# mean               14.344320                371.261312
# std                 7.287852                235.047652
# min                 4.000000                 92.000000
# 25%                11.000000                123.000000
# 50%                12.000000                365.000000
# 75%                18.000000                451.000000
# max                28.000000                846.000000
#
#        despesa.programa.codigo  despesa.acao.codigo  \
# count             23746.000000         23746.000000
# mean                  4.552851          3253.465594
# std                   2.103113           108.201474
# min                   1.000000          3000.000000
# 25%                   3.000000          3182.000000
# 50%                   4.000000          3211.000000
# 75%                   7.000000          3381.750000
# max                   9.000000          3402.000000
#
#        naturezaDespesa.categoriaEconomica.codigo  \
# count                               23002.000000
# mean                                    3.063951
# std                                     0.244671
# min                                     3.000000
# 25%                                     3.000000
# 50%                                     3.000000
# 75%                                     3.000000
# max                                     4.000000
#
#        naturezaDespesa.grupo.codigo  \
# count                  23002.000000
# mean                       2.593470
# std                        0.952129
# min                        1.000000
# 25%                        3.000000
# 50%                        3.000000
# 75%                        3.000000
# max                        6.000000
#
#        naturezaDespesa.modalidadeAplicacao.codigo  \
# count                                23002.000000
# mean                                    89.006217
# std                                      6.219204
# min                                     30.000000
# 25%                                     90.000000
# 50%                                     90.000000
# 75%                                     90.000000
# max                                     91.000000
#
#        naturezaDespesa.elemento.codigo  fonteRecurso.codigo  \
# count                     23002.000000         23757.000000
# mean                         34.565777           198.242623
# std                          18.125196           765.159506
# min                           7.000000           100.000000
# 25%                          14.000000           100.000000
# 50%                          39.000000           100.000000
# 75%                          48.000000           101.000000
# max                          97.000000         10364.000000
#
#        exercicio.exercicio  unidadeOrcamentaria.codigo  \
# count              23757.0                23757.000000
# mean                2025.0                30937.190681
# std                    0.0                31840.381645
# min                 2025.0                 2001.000000
# 25%                 2025.0                 6001.000000
# 50%                 2025.0                 7001.000000
# 75%                 2025.0                73001.000000
# max                 2025.0                90001.000000
#
#        unidadeOrcamentaria.unidadeGestora.codigo  \
# count                                    23757.0
# mean                                         0.0
# std                                          0.0
# min                                          0.0
# 25%                                          0.0
# 50%                                          0.0
# 75%                                          0.0
# max                                          0.0
#
#        unidadeOrcamentaria.unidadeOrcamentariaPai.codigo  naturezaDespesa
# count                                       23757.000000              0.0
# mean                                        30936.187229              NaN
# std                                         31840.379792              NaN
# min                                          2000.000000              NaN
# 25%                                          6000.000000              NaN
# 50%                                          7000.000000              NaN
# 75%                                         73000.000000              NaN
# max                                         90000.000000              NaN

# %%
df.shape
# Out:
# (23757, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23757 entries, 0 to 23756
# Data columns (total 32 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   listMovimentos                                          23757 non-null  object
#  1   classificacaoCompleta.classificacaoCompleta             23757 non-null  object
#  2   despesa.funcao.codigo                                   23757 non-null  int64
#  3   despesa.funcao.denominacao                              23757 non-null  object
#  4   despesa.subfuncao.codigo                                23757 non-null  int64
#  5   despesa.subfuncao.denominacao                           23757 non-null  object
#  6   despesa.programa.codigo                                 23746 non-null  float64
#  7   despesa.programa.denominacao                            23746 non-null  object
#  8   despesa.acao.codigo                                     23746 non-null  float64
#  9   despesa.acao.denominacao                                23746 non-null  object
#  10  naturezaDespesa.categoriaEconomica.codigo               23002 non-null  float64
#  11  naturezaDespesa.categoriaEconomica.codigoCompleto       23002 non-null  object
#  12  naturezaDespesa.categoriaEconomica.denominacao          23002 non-null  object
#  13  naturezaDespesa.grupo.codigo                            23002 non-null  float64
#  14  naturezaDespesa.grupo.codigoCompleto                    23002 non-null  object
#  15  naturezaDespesa.grupo.denominacao                       23002 non-null  object
#  16  naturezaDespesa.modalidadeAplicacao.codigo              23002 non-null  float64
#  17  naturezaDespesa.modalidadeAplicacao.codigoCompleto      23002 non-null  object
#  18  naturezaDespesa.modalidadeAplicacao.denominacao         23002 non-null  object
#  19  naturezaDespesa.elemento.codigo                         23002 non-null  float64
#  20  naturezaDespesa.elemento.codigoCompleto                 23002 non-null  object
#  21  naturezaDespesa.elemento.denominacao                    23002 non-null  object
#  22  fonteRecurso.codigo                                     23757 non-null  int64
#  23  fonteRecurso.denominacao                                23757 non-null  object
#  24  exercicio.exercicio                                     23757 non-null  int64
#  25  unidadeOrcamentaria.codigo                              23757 non-null  int64
#  26  unidadeOrcamentaria.denominacao                         23757 non-null  object
#  27  unidadeOrcamentaria.unidadeGestora.codigo               23757 non-null  int64
#  28  unidadeOrcamentaria.unidadeGestora.denominacao          23757 non-null  object
#  29  unidadeOrcamentaria.unidadeOrcamentariaPai.codigo       23757 non-null  int64
#  30  unidadeOrcamentaria.unidadeOrcamentariaPai.denominacao  23757 non-null  object
#  31  naturezaDespesa                                         0 non-null      float64
# dtypes: float64(7), int64(7), object(18)
# memory usage: 5.8+ MB

# %%
df["despesa.funcao.denominacao"].value_counts()
# Out:
# despesa.funcao.denominacao
# Educação                 6398
# Urbanismo                3782
# Desporto e Lazer         3493
# Administração            2951
# Assistência Social       2341
# Cultura                   904
# Comunicações              883
# Gestão Ambiental          822
# Segurança Pública         609
# Encargos Especiais        514
# Trabalho                  416
# Habitação                 273
# Agricultura               222
# Comércio e Serviços       127
# Direitos da Cidadania      18
# Saneamento                  2
# Transporte                  2
# Name: count, dtype: int64

# %%
df[df['despesa.funcao.denominacao'] == 'Educação'].head()
# Out:
#                                        listMovimentos  \
# 0   [{'dataMovimento': '2025-01-02', 'tipoMoviment...
# 6   [{'dataMovimento': '2025-01-02', 'tipoMoviment...
# 12  [{'dataMovimento': '2025-01-02', 'tipoMoviment...
# 18  [{'dataMovimento': '2025-01-02', 'tipoMoviment...
# 26  [{'dataMovimento': '2025-01-02', 'tipoMoviment...
#
#    classificacaoCompleta.classificacaoCompleta  despesa.funcao.codigo  \
# 0              0.6001.12.361.4.3172.0.33903920                     12
# 6              0.6001.12.361.4.3172.0.33903948                     12
# 12             0.6001.12.361.4.3172.0.33903916                     12
# 18             0.6001.12.361.4.3172.0.33903011                     12
# 26             0.6001.12.122.4.3386.0.33903701                     12
#
#    despesa.funcao.denominacao  despesa.subfuncao.codigo  \
# 0                    Educação                       361
# 6                    Educação                       361
# 12                   Educação                       361
# 18                   Educação                       361
# 26                   Educação                       122
#
#    despesa.subfuncao.denominacao  despesa.programa.codigo  \
# 0             Ensino Fundamental                      4.0
# 6             Ensino Fundamental                      4.0
# 12            Ensino Fundamental                      4.0
# 18            Ensino Fundamental                      4.0
# 26           Administração Geral                      4.0
#
#    despesa.programa.denominacao  despesa.acao.codigo  \
# 0               Joinville Capaz               3172.0
# 6               Joinville Capaz               3172.0
# 12              Joinville Capaz               3172.0
# 18              Joinville Capaz               3172.0
# 26              Joinville Capaz               3386.0
#
#                              despesa.acao.denominacao  ...  \
# 0   Processos administrativos ensino fundamental -...  ...
# 6   Processos administrativos ensino fundamental -...  ...
# 12  Processos administrativos ensino fundamental -...  ...
# 18  Processos administrativos ensino fundamental -...  ...
# 26                   Processos administrativos - SED   ...
#
#     fonteRecurso.codigo                          fonteRecurso.denominacao  \
# 0                   101  Receitas e Transferências de Impostos - Educação
# 6                   136                                  Salário-Educação
# 12                  101  Receitas e Transferências de Impostos - Educação
# 18                  101  Receitas e Transferências de Impostos - Educação
# 26                  101  Receitas e Transferências de Impostos - Educação
#
#    exercicio.exercicio  unidadeOrcamentaria.codigo  \
# 0                 2025                        6001
# 6                 2025                        6001
# 12                2025                        6001
# 18                2025                        6001
# 26                2025                        6001
#
#    unidadeOrcamentaria.denominacao unidadeOrcamentaria.unidadeGestora.codigo  \
# 0     Secretaria de Educação - SED                                         0
# 6     Secretaria de Educação - SED                                         0
# 12    Secretaria de Educação - SED                                         0
# 18    Secretaria de Educação - SED                                         0
# 26    Secretaria de Educação - SED                                         0
#
#     unidadeOrcamentaria.unidadeGestora.denominacao  \
# 0          Prefeitura Municipal de Joinville - PMJ
# 6          Prefeitura Municipal de Joinville - PMJ
# 12         Prefeitura Municipal de Joinville - PMJ
# 18         Prefeitura Municipal de Joinville - PMJ
# 26         Prefeitura Municipal de Joinville - PMJ
#
#    unidadeOrcamentaria.unidadeOrcamentariaPai.codigo  \
# 0                                               6000
# 6                                               6000
# 12                                              6000
# 18                                              6000
# 26                                              6000
#
#    unidadeOrcamentaria.unidadeOrcamentariaPai.denominacao  naturezaDespesa
# 0                        Secretaria de Educação - SED                  NaN
# 6                        Secretaria de Educação - SED                  NaN
# 12                       Secretaria de Educação - SED                  NaN
# 18                       Secretaria de Educação - SED                  NaN
# 26                       Secretaria de Educação - SED                  NaN
#
# [5 rows x 32 columns]

# %%
# Explode the 'listMovimentos' column to have one row per movement
df_exploded = df.explode('listMovimentos')

# Reset the index of df_exploded to make it unique
df_exploded = df_exploded.reset_index(drop=True)

# Normalize the exploded 'listMovimentos' column to extract 'dataMovimento' and 'valorMovimento'
df_movements = pd.json_normalize(df_exploded['listMovimentos'])

# Concatenate the original DataFrame (excluding the original 'listMovimentos' column) with the new movements DataFrame
df_processed = pd.concat([df_exploded.drop(columns=['listMovimentos']), df_movements], axis=1)

# Convert 'dataMovimento' to datetime
df_processed['dataMovimento'] = pd.to_datetime(df_processed['dataMovimento'])

# Convert 'valorMovimento' to numeric, coercing errors
df_processed['valorMovimento'] = pd.to_numeric(df_processed['valorMovimento'], errors='coerce')

# Display the head of the processed DataFrame
display(df_processed.head())
# Out:
#   classificacaoCompleta.classificacaoCompleta  despesa.funcao.codigo  \
# 0             0.6001.12.361.4.3172.0.33903920                     12
# 1             0.6001.12.361.4.3172.0.33903920                     12
# 2             0.6001.12.361.4.3172.0.33903920                     12
# 3             0.6001.12.361.4.3172.0.33903920                     12
# 4             0.6001.12.361.4.3172.0.33903920                     12
#
#   despesa.funcao.denominacao  despesa.subfuncao.codigo  \
# 0                   Educação                       361
# 1                   Educação                       361
# 2                   Educação                       361
# 3                   Educação                       361
# 4                   Educação                       361
#
#   despesa.subfuncao.denominacao  despesa.programa.codigo  \
# 0            Ensino Fundamental                      4.0
# 1            Ensino Fundamental                      4.0
# 2            Ensino Fundamental                      4.0
# 3            Ensino Fundamental                      4.0
# 4            Ensino Fundamental                      4.0
#
#   despesa.programa.denominacao  despesa.acao.codigo  \
# 0              Joinville Capaz               3172.0
# 1              Joinville Capaz               3172.0
# 2              Joinville Capaz               3172.0
# 3              Joinville Capaz               3172.0
# 4              Joinville Capaz               3172.0
#
#                             despesa.acao.denominacao  \
# 0  Processos administrativos ensino fundamental -...
# 1  Processos administrativos ensino fundamental -...
# 2  Processos administrativos ensino fundamental -...
# 3  Processos administrativos ensino fundamental -...
# 4  Processos administrativos ensino fundamental -...
#
#    naturezaDespesa.categoriaEconomica.codigo  ... unidadeOrcamentaria.codigo  \
# 0                                        3.0  ...                       6001
# 1                                        3.0  ...                       6001
# 2                                        3.0  ...                       6001
# 3                                        3.0  ...                       6001
# 4                                        3.0  ...                       6001
#
#   unidadeOrcamentaria.denominacao  unidadeOrcamentaria.unidadeGestora.codigo  \
# 0    Secretaria de Educação - SED                                          0
# 1    Secretaria de Educação - SED                                          0
# 2    Secretaria de Educação - SED                                          0
# 3    Secretaria de Educação - SED                                          0
# 4    Secretaria de Educação - SED                                          0
#
#   unidadeOrcamentaria.unidadeGestora.denominacao  \
# 0        Prefeitura Municipal de Joinville - PMJ
# 1        Prefeitura Municipal de Joinville - PMJ
# 2        Prefeitura Municipal de Joinville - PMJ
# 3        Prefeitura Municipal de Joinville - PMJ
# 4        Prefeitura Municipal de Joinville - PMJ
#
#   unidadeOrcamentaria.unidadeOrcamentariaPai.codigo  \
# 0                                              6000
# 1                                              6000
# 2                                              6000
# 3                                              6000
# 4                                              6000
#
#    unidadeOrcamentaria.unidadeOrcamentariaPai.denominacao naturezaDespesa  \
# 0                       Secretaria de Educação - SED                  NaN
# 1                       Secretaria de Educação - SED                  NaN
# 2                       Secretaria de Educação - SED                  NaN
# 3                       Secretaria de Educação - SED                  NaN
# 4                       Secretaria de Educação - SED                  NaN
#
#   dataMovimento          tipoMovimento valorMovimento
# 0    2025-01-02     Emissão de empenho        50360.0
# 1    2025-03-25  Empenho em liquidação        10072.0
# 2    2025-03-28  Liquidação de empenho        10072.0
# 3    2025-04-11  Empenho em liquidação        24172.8
# 4    2025-04-14  Liquidação de empenho        24172.8
#
# [5 rows x 34 columns]

# %%
df_processed["despesa.funcao.denominacao"].value_counts()
# Out:
# despesa.funcao.denominacao
# Educação                 29278
# Urbanismo                20124
# Administração            14323
# Desporto e Lazer         12640
# Assistência Social        9359
# Gestão Ambiental          4244
# Comunicações              3869
# Cultura                   3857
# Segurança Pública         2737
# Encargos Especiais        2501
# Trabalho                  1713
# Habitação                 1065
# Agricultura                976
# Comércio e Serviços        384
# Direitos da Cidadania       69
# Transporte                   7
# Saneamento                   4
# Name: count, dtype: int64

# %%
df_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107150 entries, 0 to 107149
# Data columns (total 34 columns):
#  #   Column                                                  Non-Null Count   Dtype
# ---  ------                                                  --------------   -----
#  0   classificacaoCompleta.classificacaoCompleta             107150 non-null  object
#  1   despesa.funcao.codigo                                   107150 non-null  int64
#  2   despesa.funcao.denominacao                              107150 non-null  object
#  3   despesa.subfuncao.codigo                                107150 non-null  int64
#  4   despesa.subfuncao.denominacao                           107150 non-null  object
#  5   despesa.programa.codigo                                 107128 non-null  float64
#  6   despesa.programa.denominacao                            107128 non-null  object
#  7   despesa.acao.codigo                                     107128 non-null  float64
#  8   despesa.acao.denominacao                                107128 non-null  object
#  9   naturezaDespesa.categoriaEconomica.codigo               93012 non-null   float64
#  10  naturezaDespesa.categoriaEconomica.codigoCompleto       93012 non-null   object
#  11  naturezaDespesa.categoriaEconomica.denominacao          93012 non-null   object
#  12  naturezaDespesa.grupo.codigo                            93012 non-null   float64
#  13  naturezaDespesa.grupo.codigoCompleto                    93012 non-null   object
#  14  naturezaDespesa.grupo.denominacao                       93012 non-null   object
#  15  naturezaDespesa.modalidadeAplicacao.codigo              93012 non-null   float64
#  16  naturezaDespesa.modalidadeAplicacao.codigoCompleto      93012 non-null   object
#  17  naturezaDespesa.modalidadeAplicacao.denominacao         93012 non-null   object
#  18  naturezaDespesa.elemento.codigo                         93012 non-null   float64
#  19  naturezaDespesa.elemento.codigoCompleto                 93012 non-null   object
#  20  naturezaDespesa.elemento.denominacao                    93012 non-null   object
#  21  fonteRecurso.codigo                                     107150 non-null  int64
#  22  fonteRecurso.denominacao                                107150 non-null  object
#  23  exercicio.exercicio                                     107150 non-null  int64
#  24  unidadeOrcamentaria.codigo                              107150 non-null  int64
#  25  unidadeOrcamentaria.denominacao                         107150 non-null  object
#  26  unidadeOrcamentaria.unidadeGestora.codigo               107150 non-null  int64
#  27  unidadeOrcamentaria.unidadeGestora.denominacao          107150 non-null  object
#  28  unidadeOrcamentaria.unidadeOrcamentariaPai.codigo       107150 non-null  int64
#  29  unidadeOrcamentaria.unidadeOrcamentariaPai.denominacao  107150 non-null  object
#  30  naturezaDespesa                                         0 non-null       float64
#  31  dataMovimento                                           107150 non-null  datetime64[ns]
#  32  tipoMovimento                                           107150 non-null  object
#  33  valorMovimento                                          107150 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(7), object(18)
# memory usage: 27.8+ MB

# %%
import plotly.express as px

# %%
gastos_jlle = df_processed.groupby("despesa.funcao.denominacao")["valorMovimento"].sum().sort_values(ascending=False).reset_index()

fig = px.bar(gastos_jlle,
             x="despesa.funcao.denominacao",
             y="valorMovimento",
             title= 'Gastos 2025',
             labels={'despesa.funcao.denominacao': 'Setores', 'valorMovimento': 'Total Gasto'}
             )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d802ef72-76f7-419b-bdbd-f3019c0d90cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d802ef72-76f7-419b-bdbd-f3019c0d90cd")) {                    Plotly.newPlot(                        "d802ef72-76f7-419b-bdbd-f3019c0d90cd",                        [{"alignmentgroup":"True","hovertemplate":"Setores=%{x}\u003cbr\u003eTotal Gasto=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Educação","Urbanismo","Encargos Especiais","Administração","Gestão Ambiental","Assistência Social","Cultura","Segurança Pública","Desporto e Lazer","Comunicações","Trabalho","Habitação","Agricultura","Comércio e Serviços","Transporte","Direitos da Cidadania","Saneamento"],"xaxis":"x","y":[6977681782.3,6041337032.81,1354121277.89,974171248.54,415227483.8,305465290.89,249793134.69,228719044.41,179026927.31,105041096.21,52568192.27,50340465.83,29367175.21,20868311.83,5703593.05,124178.83,4000.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"typ ...

# %%
df_processed[df_processed['despesa.funcao.denominacao'] == 'Cultura'].head()
# Out:
#     classificacaoCompleta.classificacaoCompleta  despesa.funcao.codigo  \
# 195            0.74001.13.122.3.3258.0.33903917                     13
# 196            0.74001.13.122.3.3258.0.33903917                     13
# 197            0.74001.13.122.3.3258.0.33903917                     13
# 198            0.74001.13.122.3.3258.0.33903917                     13
# 204            0.74001.13.122.3.3258.0.33903917                     13
#
#     despesa.funcao.denominacao  despesa.subfuncao.codigo  \
# 195                    Cultura                       122
# 196                    Cultura                       122
# 197                    Cultura                       122
# 198                    Cultura                       122
# 204                    Cultura                       122
#
#     despesa.subfuncao.denominacao  despesa.programa.codigo  \
# 195           Administração Geral                      3.0
# 196           Administração Geral                      3.0
# 197           Administração Geral                      3.0
# 198           Administração Geral                      3.0
# 204           Administração Geral                      3.0
#
#     despesa.programa.denominacao  despesa.acao.codigo  \
# 195            Joinville Simples               3258.0
# 196            Joinville Simples               3258.0
# 197            Joinville Simples               3258.0
# 198            Joinville Simples               3258.0
# 204            Joinville Simples               3258.0
#
#                 despesa.acao.denominacao  \
# 195  Processos administrativos – SECULT
# 196  Processos administrativos – SECULT
# 197  Processos administrativos – SECULT
# 198  Processos administrativos – SECULT
# 204  Processos administrativos – SECULT
#
#      naturezaDespesa.categoriaEconomica.codigo  ...  \
# 195                                        3.0  ...
# 196                                        3.0  ...
# 197                                        3.0  ...
# 198                                        3.0  ...
# 204                                        3.0  ...
#
#     unidadeOrcamentaria.codigo           unidadeOrcamentaria.denominacao  \
# 195                      74001  Secretaria de Cultura e Turismo - SECULT
# 196                      74001  Secretaria de Cultura e Turismo - SECULT
# 197                      74001  Secretaria de Cultura e Turismo - SECULT
# 198                      74001  Secretaria de Cultura e Turismo - SECULT
# 204                      74001  Secretaria de Cultura e Turismo - SECULT
#
#      unidadeOrcamentaria.unidadeGestora.codigo  \
# 195                                          0
# 196                                          0
# 197                                          0
# 198                                          0
# 204                                          0
#
#     unidadeOrcamentaria.unidadeGestora.denominacao  \
# 195        Prefeitura Municipal de Joinville - PMJ
# 196        Prefeitura Municipal de Joinville - PMJ
# 197        Prefeitura Municipal de Joinville - PMJ
# 198        Prefeitura Municipal de Joinville - PMJ
# 204        Prefeitura Municipal de Joinville - PMJ
#
#     unidadeOrcamentaria.unidadeOrcamentariaPai.codigo  \
# 195                                             74000
# 196                                             74000
# 197                                             74000
# 198                                             74000
# 204                                             74000
#
#      unidadeOrcamentaria.unidadeOrcamentariaPai.denominacao naturezaDespesa  \
# 195           Secretaria de Cultura e Turismo - SECULT                  NaN
# 196           Secretaria de Cultura e Turismo - SECULT                  NaN
# 197           Secretaria de Cultura e Turismo - SECULT                  NaN
# 198           Secretaria de Cultura e Turismo - SECULT                  NaN
# 204           Secretaria de Cultura e Turismo - SECULT                  NaN
#
#     dataMovimento          tipoMovimento valorMovimento
# 195    2025-01-02     Emissão de empenho        3100.01
# 196    2025-02-14  Empenho em liquidação        3100.01
# 197    2025-02-19  Liquidação de empenho        3100.01
# 198    2025-03-18   Pagamento de empenho        3100.01
# 204    2025-01-02     Emissão de empenho        1983.30
#
# [5 rows x 34 columns]

# %%
df_processed[df_processed['despesa.funcao.denominacao'] == 'Cultura']['despesa.subfuncao.denominacao'].value_counts()
# Out:
# despesa.subfuncao.denominacao
# Difusão Cultural                                  1961
# Administração Geral                               1168
# Patrimônio Histórico, Artístico e Arqueológico     448
# Infra-Estrutura Urbana                             280
# Name: count, dtype: int64
